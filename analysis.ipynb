# %%
import pandas as pd

# %%
# Read data in
df = pd.read_csv('input.csv')
df.head()
# Out:
#   Set #         Name  Normal/Holo  Rev  Rev - M
# 0    #1    Bulbasaur            6  NaN      1.0
# 1    #2      Ivysaur            4  1.0      NaN
# 2    #3  Venusaur ex            2  NaN      NaN
# 3    #4   Charmander            7  1.0      NaN
# 4    #5   Charmeleon            3  NaN      1.0

# %%
# fill nulls with 0
df.fillna(value=0, inplace=True)

# %%
# change column type to ints
df['Rev'] = df['Rev'].astype('int64')
df['Rev - M'] = df['Rev - M'].astype('int64')

# %%
# 1st condition, remove ex
# 2nd condition, 
filtered_df = df[~df['Name'].str.contains('ex')].loc[0:164]
filtered_df.head()
# Out:
#   Set #        Name  Normal/Holo  Rev  Rev - M
# 0    #1   Bulbasaur            6    0        1
# 1    #2     Ivysaur            4    1        0
# 3    #4  Charmander            7    1        0
# 4    #5  Charmeleon            3    0        1
# 6    #7    Squirtle            6    1        0

# %%
# As of 7/30/2024, these are the cards I still need to complete the 151 sv2a set
missing_rev_df = filtered_df[filtered_df['Rev'] == 0]
missing_rev_df
# Out:
#     Set #        Name  Normal/Holo  Rev  Rev - M
# 0      #1   Bulbasaur            6    0        1
# 4      #5  Charmeleon            3    0        1
# 18    #19     Rattata            5    0        1
# 46    #47    Parasect            2    0        1
# 117  #118     Goldeen            9    0        1
# 148  #149   Dragonite            4    0        0

# %%
missing_mast_df = filtered_df[filtered_df['Rev - M'] != 0]
missing_mast_df
# Out:
#     Set #              Name  Normal/Holo  Rev  Rev - M
# 0      #1         Bulbasaur            6    0        1
# 4      #5        Charmeleon            3    0        1
# 7      #8         Wartortle            6    2        1
# 12    #13            Weedle            7    2        1
# 18    #19           Rattata            5    0        1
# 27    #28         Sandslash            6    1        1
# 32    #33          Nidorino            7    3        1
# 40    #41             Zubat           10    2        1
# 44    #45         Vileplume            5    1        1
# 46    #47          Parasect            2    0        1
# 50    #51           Dugtrio            7    4        1
# 54    #55           Golduck            5    3        1
# 98    #99           Kingler            6    4        1
# 102  #103         Exeggutor            4    1        1
# 117  #118           Goldeen            9    0        1
# 127  #128            Tauros            4    1        1
# ...

# %% [markdown]
# # Cards Needed:
#
# ### Reverse (Pokeball) Holos:
# * #1 Bulbasaur
# * #5 Charmeleon
# * #19 Rattata
# * #47 Parasect
# * #118 Goldeen
# * #149 Dragonite
#
# ### Masterball Holos:
# Too many to list
